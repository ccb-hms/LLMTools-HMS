# %% [markdown]
# ## Zero Shot Classifier

# %%
from sklearn.metrics import classification_report
class_names= ['ODONTO: primary caries','DIAGNOSIS: previously endodontically treated','PERIO: suppuration',
 'DIAGNOSIS: generalized severe chronic periodontitis',
 'ODONTO: advanced/primary caries']
label2id = {class_names[i]: i for i in range(len(class_names))}
y_true = X['GT'].map(label2id).values
y_pred = X['prediction'].map(label2id).values
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#                                                      precision    recall  f1-score   support
#
#                              ODONTO: primary caries       0.98      0.86      0.91     16219
#        DIAGNOSIS: previously endodontically treated       1.00      0.61      0.76      4564
#                                  PERIO: suppuration       0.92      1.00      0.95      2664
# DIAGNOSIS: generalized severe chronic periodontitis       0.98      0.72      0.83      1726
#                     ODONTO: advanced/primary caries       0.21      0.91      0.35      1222
#
#                                            accuracy                           0.82     26395
#                                           macro avg       0.82      0.82      0.76     26395
#                                        weighted avg       0.94      0.82      0.86     26395
