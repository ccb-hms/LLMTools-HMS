# %% [markdown]
# ### Getting Started with VLLM ###

# %%
import sys
from openai import OpenAI

# %load_ext autoreload
# %autoreload 2
import llmtools
print(f'Package version: {llmtools.__version__}')
print(f'Authors: {llmtools.__authors__}')
# Out:
# Package version: v0.0.1
# Authors: The Core for Computational Biomedicine at Harvard Medical School
# https://dbmi.hms.harvard.edu/about-dbmi/core-computational-biomedicine

# %%
client = OpenAI(
    base_url="http://vllm:8000/v1",  # <-- service name on the docker network
    api_key="vllmkey"             # vLLM doesn't require a real key by default
)

# %%
resp = client.completions.create(
    model="opt",
    prompt="User: Write a short poem.\nAssistant:",
    max_tokens=800,
)
print(resp.choices[0].text)
# Out:
#  Harness into every state of reality and collect on depth.
# Date: 12/5/1999 1:15 AM
# Place: Rights Pub. 300 Broadway, Suite 639
#
# "Men's Zodiac"_______resents visions and worries of...
#
# "Men's Zodiac"_______resents visions and worries of...
#
# Published online at 20:35 this week and tomorrow. The graphic novel is called "Zombieland No More". A moments images of young dogs growing up in the mountains of Nachibori, Japan. From the background sounds of war, war crimes and genocide in the world outside of Japan, it goes from crazy to hilarious. "Men's Zodiac"XXX is the third in a series that has been collecting graphic novels and graphic novels for GiveMeNothingExminassianeries.com, who cares about fungal infection. New series: "If I Bought More Mud a Worthy Time".
